# %%
import numpy as np
import pandas as pd

# %%
# football players
df = pd.read_csv('data/data_sf.xls')

# %%
df.groupby('Nationality').Age.std()
# Out:
# Nationality
# Afghanistan    2.645751
# Albania        4.141286
# Algeria        4.037921
# Andorra             NaN
# Angola         3.400980
#                  ...
# Uzbekistan     0.707107
# Venezuela      4.290540
# Wales          4.909954
# Zambia         3.600926
# Zimbabwe       4.558265
# Name: Age, Length: 156, dtype: float64

# %%
small_df = df[df.columns[1:8]].head(25)
small_df
# Out:
#                  Name  Age Nationality                 Club      Value  \
# 0            L. Messi   31   Argentina         FC Barcelona  110500000
# 1   Cristiano Ronaldo   33    Portugal             Juventus   77000000
# 2           Neymar Jr   26      Brazil  Paris Saint-Germain  118500000
# 3              De Gea   27       Spain    Manchester United   72000000
# 4        K. De Bruyne   27     Belgium      Manchester City  102000000
# 5           E. Hazard   27     Belgium              Chelsea   93000000
# 6           L. Modrić   32     Croatia          Real Madrid   67000000
# 7           L. Suárez   31     Uruguay         FC Barcelona   80000000
# 8        Sergio Ramos   32       Spain          Real Madrid   51000000
# 9            J. Oblak   25    Slovenia      Atlético Madrid   68000000
# 10     R. Lewandowski   29      Poland    FC Bayern München   77000000
# 11           T. Kroos   28     Germany          Real Madrid   76500000
# ...

# %%
s = small_df.Nationality.value_counts()
print(f"The number of football players from Germany is {s['Germany']}.")
s[s>1]
# Out:
# The number of football players from Germany is 3.
# Spain        4
# Belgium      3
# Germany      3
# Argentina    3
# Uruguay      3
# France       2
# Name: Nationality, dtype: int64

# %%
df.Club.nunique()
# Out:
# 650

# %%
s = df.Club.value_counts()
s[s == s.max()]
# Out:
# V-Varen Nagasaki    30
# Shonan Bellmare     30
# Name: Club, dtype: int64

# %%
s[s == s.min()]
# Out:
# Atlético Mineiro    6
# Name: Club, dtype: int64

# %%
s = df.Position.value_counts(normalize=True)
s[s > 0.1]
# Out:
# GK    0.127239
# ST    0.117237
# CB    0.108785
# Name: Position, dtype: float64

# %%
s[s < 0.01]
# Out:
# LS     0.009382
# RS     0.008839
# RWB    0.005428
# LWB    0.004652
# CF     0.003954
# LF     0.000620
# RF     0.000465
# LAM    0.000465
# RAM    0.000388
# Name: Position, dtype: float64

# %%
small_df = df[df.columns[0:7]].head(25)

s = small_df['Wage'].value_counts(bins=4)

display(s)
# Out:
# (211750.0, 329500.0]     9
# (93528.999, 211750.0]    8
# (329500.0, 447250.0]     6
# (447250.0, 565000.0]     2
# Name: Wage, dtype: int64

# %%
s.index
# Out:
# IntervalIndex([(211750.0, 329500.0], (93528.999, 211750.0], (329500.0, 447250.0], (447250.0, 565000.0]],
#               closed='right',
#               dtype='interval[float64]')

# %%
s.index[3].left, s.index[3].right
# Out:
# (447250.0, 565000.0)

# %%
s = df.FKAccuracy.value_counts(bins=5)
s
# Out:
# (21.2, 39.4]     4859
# (39.4, 57.6]     3957
# (57.6, 75.8]     2108
# (2.908, 21.2]    1760
# (75.8, 94.0]      213
# Name: FKAccuracy, dtype: int64

# %%
assert len(df.Nationality.unique()) == df.Nationality.nunique() == len(df.Nationality.value_counts()) == \
    len(df.groupby('Nationality')['Name'].count())

# %%
# to return the result of the value_counts() function as a dataframe
s_df = df.Nationality.value_counts().reset_index()
s_df.columns = ['Nationality','Players Count']
s_df
# Out:
#     Nationality  Players Count
# 0       England           1368
# 1       Germany            919
# 2         Spain            671
# 3        France            614
# 4     Argentina            574
# ..          ...            ...
# 151        Oman              1
# 152    Ethiopia              1
# 153   Mauritius              1
# 154      Jordan              1
# 155       Malta              1
#
# [156 rows x 2 columns]

# %%
# У какого процента испанских футболистов (Nationality = 'Spain') зарплата (Wage) находится в пределах 25% минимума 
# от наблюдаемого уровня зарплат среди испанских игроков? Ответ дайте в виде целого числа (округлите полученный 
# результат) без знака %.
sliced_data = df[df.Nationality == 'Spain'].Wage.value_counts(normalize=True, bins=4)
sliced_data
# Out:
# (620.999, 95750.0]      0.970194
# (95750.0, 190500.0]     0.016393
# (190500.0, 285250.0]    0.008942
# (285250.0, 380000.0]    0.004471
# Name: Wage, dtype: float64

# %%
# Укажите количество национальностей (Nationality), к которым относятся футболисты, выступающие за клуб (Club) 
# "Manchester United".
df[df.Club == 'Manchester United'].Nationality.nunique()
# Out:
# 13

# %%
# С помощью функции unique определите двух футболистов из Бразилии (Nationality = 'Brazil'), выступающих за клуб 
# (Club) 'Juventus'. Перечислите их имена (Name, как в датафрейме) через запятую в алфавитном порядке.
df[(df.Nationality == 'Brazil')&(df.Club == 'Juventus')].Name.unique()
# Out:
# array(['Alex Sandro', 'Douglas Costa'], dtype=object)

# %%
# Укажите, какой из клубов (Club) насчитывает большее количество футболистов возрастом (Age) старше 35 лет.
df[df.Age > 35].Club.value_counts()
# Out:
# Hokkaido Consadole Sapporo        4
# Club Atlético Huracán             4
# Club Atlético Talleres            3
# Club Atlético Colón               3
# Gimnasia y Esgrima La Plata       3
#                                  ..
# Sporting Lokeren                  1
# Birmingham City                   1
# RCD Espanyol                      1
# Guangzhou Evergrande Taobao FC    1
# Boavista FC                       1
# Name: Club, Length: 212, dtype: int64

# %%
# С помощью функции value_counts с параметром bins разбейте всех футболистов родом из Аргентины (Nationality = 
# 'Argentina') на 4 равные группы по возрасту. Сколько футболистов в возрасте от 34,75 до 41 года в сборной Аргентины?
df[df.Nationality == 'Argentina'].Age.value_counts(bins=4)
# Out:
# (22.25, 28.5]      200
# (15.974, 22.25]    197
# (28.5, 34.75]      128
# (34.75, 41.0]       49
# Name: Age, dtype: int64

# %%
# Сколько процентов футболистов из Испании (Nationality = 'Spain') имеют возраст (Age) 21 год? Введите с точностью 
# до 2 знаков после запятой без указания знака % (например, 12.35).
df[df.Nationality == 'Spain'].Age.value_counts(normalize=True)
# Out:
# 21    0.117735
# 22    0.095380
# 20    0.077496
# 23    0.071535
# 25    0.064083
# 27    0.062593
# 24    0.059613
# 28    0.053651
# 26    0.053651
# 29    0.047690
# 19    0.047690
# 18    0.038748
# 30    0.038748
# 31    0.032787
# 32    0.032787
# 33    0.031297
# 34    0.022355
# 17    0.013413
# 35    0.011923
# 36    0.010432
# 37    0.008942
# 39    0.002981
# 16    0.002981
# 38    0.001490
# Name: Age, dtype: float64

# %%
df.groupby(['Club'])
# Это объект группировки, он хранит в себе информацию о том, какие строки датафрейма (по индексным номерам) 
# соответствуют определенной группе (в нашем случае определенному клубу).

# %%
df.groupby(['Club']).groups
# Out:
# {' SSV Jahn Regensburg': [1642, 2284, 2374, 2401, 2575, 2583, 2850, 2868, 3418, 3908, 3989, 4154, 5151, 5177, 5525, 5885, 6070, 6679, 7173, 7477, 8905, 9061, 10825, 12482], '1. FC Heidenheim 1846': [1060, 1805, 1978, 2050, 2066, 2926, 3584, 3605, 4312, 4457, 4783, 6818, 7160, 7166, 7460, 9475, 10052, 10565, 11217, 12236], '1. FC Kaiserslautern': [2931, 3590, 4270, 4413, 4475, 4483, 4709, 4779, 5079, 5325, 5403, 5855, 5917, 7295, 8784, 9496, 9964, 10019, 10122, 10671, 11500, 11970, 12222], '1. FC Köln': [166, 379, 899, 1399, 3415, 6904, 7052, 8892, 12171, 12376], '1. FC Magdeburg': [1967, 2069, 2152, 2569, 2886, 3030, 3300, 3332, 4436, 4913, 5002, 5033, 5493, 5768, 6329, 7046, 7595, 8387, 9626, 11125, 11400], '1. FC Nürnberg': [724, 1208, 1254, 1920, 4775, 5265, 5556, 5985, 8590, 8632, 9217, 9858, 10480], '1. FC Union Berlin': [1422, 1493, 2530, 2876, 3635, 3844, 4683, 4826, 11038, 11296, 12340], '1. FSV Mainz 05': [545, 670, 765, 1201, 1342, 6218, 6868, 8792, 10293, 10561, 10566], 'A
# ...

# %%
grouped_df = df.groupby(['Club']).sum()
grouped_df
# Out:
#                        Unnamed: 0  Age     Value    Wage  Crossing  Finishing  \
# Club
#  SSV Jahn Regensburg       129124  609  15195000   90000      1104        944
# 1. FC Heidenheim 1846      117834  473  18290000   76000       961        860
# 1. FC Kaiserslautern       167351  544  11195000   33000      1106        918
# 1. FC Köln                  54865  225  46810000   92000       444        357
# 1. FC Magdeburg            116731  515  57525000   84000       948        903
# ...                           ...  ...       ...     ...       ...        ...
# Zagłębie Sosnowiec         220803  656   6815000   27000      1161       1007
# Çaykur Rizespor            119137  557  27515000  118000      1110        921
# Örebro SK                  224465  622   8465000   36000      1114        974
# Östersunds FK              136103  478  11030000   39000       944        805
# Śląsk Wrocław              172358  628   9170000   50000      1058       1054
#
# ...

# %%
grouped_df.loc['Ajax']
# Out:
# Unnamed: 0             26041
# Age                      275
# Value              152250000
# Wage                  158000
# Crossing                 844
# Finishing                723
# HeadingAccuracy          848
# ShortPassing             940
# Volleys                  696
# Dribbling                932
# Curve                    779
# FKAccuracy               680
# LongPassing              878
# BallControl              951
# Acceleration             944
# SprintSpeed              969
# Agility                  969
# Reactions                924
# Balance                  918
# ShotPower                876
# Jumping                  915
# Stamina                  974
# Strength                 896
# LongShots                720
# Aggression               847
# Interceptions            801
# Positioning              813
# Vision                   881
# Penalties                710
# Composure                929
# Marking                  750
# StandingTackle           814
# ...

# %%
grouped_df.loc['Ajax'].Wage
# Out:
# 158000

# %%
grouped_df = df.groupby(['Club'])['Wage'].sum().sort_values(ascending=False)
grouped_df.head(5)
# Out:
# Club
# Real Madrid          4138000
# FC Barcelona         3967000
# Manchester City      3097000
# Manchester United    2357000
# Juventus             2335000
# Name: Wage, dtype: int64

# %%
grouped_df = df.groupby('Position').Wage.sum().sort_values(ascending=False)
grouped_df[grouped_df > 5000000]
# Out:
# Position
# ST     11873000
# GK      8784000
# CB      7476000
# CM      6194000
# LB      6096000
# CAM     5500000
# LM      5440000
# RM      5098000
# RB      5034000
# Name: Wage, dtype: int64

# %%
df.groupby('Position')[['Wage', 'Value']].mean().sort_values('Value', ascending=False)
# Out:
#                    Wage         Value
# Position
# LF         75125.000000  2.736250e+07
# RF        119000.000000  2.636583e+07
# LAM        61000.000000  1.324583e+07
# RAM        11800.000000  8.345000e+06
# LS         15421.487603  5.848430e+06
# LCM        13497.854077  4.318090e+06
# RCM        13504.166667  4.217604e+06
# RS         13482.456140  3.645833e+06
# LW         12169.421488  3.603099e+06
# RW         13822.784810  3.495738e+06
# LDM        10243.243243  3.369459e+06
# RCB        11270.334928  3.009055e+06
# CAM         8688.783570  2.963199e+06
# RDM        11282.608696  2.692717e+06
# LCB         9753.056235  2.636516e+06
# LM          7472.527473  2.466174e+06
# ST          7852.513228  2.157252e+06
# RM          6655.352480  2.138734e+06
# LWB         5783.333333  1.931333e+06
# CF          4862.745098  1.848627e+06
# CDM         7121.562952  1.658900e+06
# CM          5805.060918  1.617465e+06
# RWB         6000.000000  1.555571e+06
# ...

# %%
data = df.groupby('Club').Wage.agg(['mean', 'median']).reset_index()
data.columns = ['Club', 'my_mean', 'my_median']
len(data[data.my_mean == data.my_median])
# Out:
# 52

# %%
data[data.my_mean == data.my_median].sort_values('my_mean', ascending=False).iloc[[0]]
# Out:
#          Club  my_mean  my_median
# 168  Cruzeiro  13000.0      13000

# %%
data = df.groupby('Club').Wage.sum()
data[data.index == 'Chelsea']
# Out:
# Club
# Chelsea    2035000
# Name: Wage, dtype: int64

# %%
df[(df.Nationality == 'Argentina') & (df.Age == 20)].Wage.max()
# Out:
# 54000

# %%
df[(df.Nationality == 'Argentina') & (df.Age == 30)].Wage.max()
# Out:
# 300000

# %%
df[(df.Nationality == 'Argentina') & (df.Age == 30)].Wage.min()
# Out:
# 1000

# %%
df[(df.Nationality == 'Argentina') & (df.Club == 'FC Barcelona')][['Strength', 'Balance']]
# Out:
#    Strength  Balance
# 0        59       95

# %%
pivot = df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])].pivot_table(values=['Wage'],
index=['Nationality'],
columns=['Club'],
aggfunc='sum',
margins=True)

# %%
pivot
# Out:
#                            Wage                                           \
# Club               FC Barcelona   Juventus Manchester United Real Madrid
# Nationality
# Argentina              565000.0   205000.0          206000.0         NaN
# Belgium                110000.0        NaN          230000.0    240000.0
# Bosnia Herzegovina          NaN   180000.0               NaN         NaN
# Brazil                 465000.0   335000.0           91000.0    570000.0
# Chile                  205000.0        NaN          215000.0         NaN
# Costa Rica                  NaN        NaN               NaN    195000.0
# Croatia                260000.0   160000.0               NaN    420000.0
# Dominican Republic          NaN        NaN               NaN    140000.0
# Ecuador                     NaN        NaN          120000.0         NaN
# England                     NaN        NaN          478000.0         NaN
# France                 495000.0   145000.0          375000.0    459000.0
# ...

# %%
# Сводная таблица, показывающая максимальные зарплаты игроков на разных позициях, играющих за разные клубы
table = df.pivot_table(values='Wage', aggfunc='max', margins=True, index='Club', columns='Position', fill_value=0)

# %%
table.loc['Manchester City']['GK']
# Out:
# 125000.0

# %%
table.loc['Manchester City', 'GK']
# Out:
# 125000.0

# %%
table
# Out:
# Position                  CAM      CB     CDM     CF      CM      GK     LAM  \
# Club
#  SSV Jahn Regensburg        0    5000    5000      0    4000    5000       0
# 1. FC Heidenheim 1846    5000    7000       0      0    1000    4000       0
# 1. FC Kaiserslautern        0    1000    1000      0       0    1000       0
# 1. FC Köln                  0    1000   10000      0    3000   25000       0
# 1. FC Magdeburg             0    7000       0   4000       0    6000       0
# ...                       ...     ...     ...    ...     ...     ...     ...
# Çaykur Rizespor         11000   11000   13000      0       0    3000       0
# Örebro SK                   0    2000       0      0    1000    2000       0
# Östersunds FK            1000    1000       0   3000    8000    1000       0
# Śląsk Wrocław               0    1000    3000      0    1000    2000       0
# All                    205000  205000  315000  43000  175000  260000  315000
#
# ...

# %%
pivot = df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])].pivot_table(
    values=['Name'],
    index=['Nationality'],
    columns=['Club'],
    aggfunc='count',
    fill_value=0
)
display(pivot)
# Out:
#                            Name
# Club               FC Barcelona Juventus Manchester United Real Madrid
# Nationality
# Argentina                     1        1                 2           0
# Belgium                       1        0                 1           1
# Bosnia Herzegovina            0        1                 0           0
# Brazil                        2        2                 1           2
# Chile                         1        0                 1           0
# Costa Rica                    0        0                 0           1
# Croatia                       1        1                 0           1
# Dominican Republic            0        0                 0           1
# Ecuador                       0        0                 1           0
# England                       0        0                 6           0
# France                        3        1                 2           3
# Germany                       1        1                 0           1
# ...

# %%
pivot.loc['Argentina']['Name']['Manchester United']
# Out:
# 2

# %%
table = df.pivot_table(values='Name', aggfunc='count', index='Club', columns='Position', fill_value=0)
table
# Out:
# Position               CAM  CB  CDM  CF  CM  GK  LAM  LB  LCB  LCM  ...  RB  \
# Club                                                                ...
#  SSV Jahn Regensburg     0   5    1   0   2   3    0   2    0    0  ...   2
# 1. FC Heidenheim 1846    1   3    0   0   1   2    0   2    1    0  ...   2
# 1. FC Kaiserslautern     0   3    3   0   0   3    0   2    1    0  ...   2
# 1. FC Köln               0   1    1   0   2   3    0   0    0    0  ...   1
# 1. FC Magdeburg          0   4    0   1   0   3    0   1    1    1  ...   0
# ...                    ...  ..  ...  ..  ..  ..  ...  ..  ...  ...  ...  ..
# Zagłębie Sosnowiec       3   2    2   0   0   3    0   3    1    0  ...   1
# Çaykur Rizespor          1   2    5   0   0   3    0   2    1    0  ...   3
# Örebro SK                0   4    0   0   1   3    0   0    1    1  ...   0
# Östersunds FK            1   1    0   1   3   3    0   2    1    1  ...   1
# ...

# %%
table.loc[:, 'GK'].mean()
# Out:
# 2.5246153846153847

# %%
a = table.loc[:, 'CM']
a.value_counts()
# Out:
# 1    211
# 2    149
# 0    136
# 3     89
# 4     39
# 5     21
# 6      5
# Name: CM, dtype: int64

# %%
pivot = df.pivot_table(values='Wage', index='Club', columns='Nationality', aggfunc='sum')
pivot.loc['AS Monaco']['Russia']
# Out:
# 61000.0

# %%
# Создайте сводную таблицу, содержащую сведения о средней скорости футболистов (SprintSpeed), 
# занимающих разные позиции (Position) в разных футбольных клубах (Club).
df.pivot_table(values='SprintSpeed', index='Club', columns='Position', aggfunc='mean', fill_value=0).loc[:, 'ST'].sort_values(ascending=False)
# Out:
# Club
# Vitória                  91.000000
# Sydney FC                88.000000
# CD Lugo                  87.000000
# Brøndby IF               84.666667
# Leicester City           84.500000
#                            ...
# Málaga CF                 0.000000
# PFC CSKA Moscow           0.000000
# Stade Rennais FC          0.000000
# Standard de Liège         0.000000
# Sporting de Charleroi     0.000000
# Name: ST, Length: 650, dtype: float64
